# %% [markdown]
# <a href="https://colab.research.google.com/github/ChorapalliPavanKumar123/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
df=pd.DataFrame({"Roll No":["1A","2A","3A"],"Name":["Ram","Rajesh","Suresh"]}) 
df
# Out:
#   Roll No    Name
# 0      1A     Ram
# 1      2A  Rajesh
# 2      3A  Suresh

# %%
df=pd.read_csv("students_placement_data.csv") 
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      68.0
# 3        4      M       A            71.0                      70.4
# 4        5      M       A             NaN                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              71.45         0                                yes
# 2              45.26        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(df.isna().any())
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                         True
# inter_Diploma_percentage              False
# B.Tech_percentage                     False
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df.describe()
# Out:
#           Roll No  SSC Percentage  inter_Diploma_percentage  \
# count  117.000000      116.000000                117.000000
# mean    59.000000       80.474569                 80.772906
# std     33.919021        8.836079                 11.267248
# min      1.000000       47.800000                 52.200000
# 25%     30.000000       76.622500                 73.400000
# 50%     59.000000       82.745000                 83.600000
# 75%     88.000000       87.025000                 90.000000
# max    117.000000       93.660000                 96.900000
#
#        B.Tech_percentage    Backlogs
# count         117.000000  117.000000
# mean           62.943419    4.111111
# std            12.064306    6.335148
# min            31.200000    0.000000
# 25%            54.180000    0.000000
# 50%            64.360000    0.000000
# 75%            72.570000    7.000000
# max            88.100000   25.000000

# %%
df.shape
# Out:
# (117, 9)

# %%
host_day=pd.read_csv("hostlers_day_scholars.csv") 
host_day.head()
# Out:
#   hostler/days scholar
# 0                    d
# 1                    d
# 2                    d
# 3                    d
# 4                    h

# %%
host_day.shape
# Out:
# (117, 1)

# %%
df=pd.read_csv("students_placement_data.csv")
df["hostler/days scholar"]=host_day.values
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      68.0
# 3        4      M       A            71.0                      70.4
# 4        5      M       A             NaN                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              71.45         0                                yes
# 2              45.26        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status hostler/days scholar
# 0       Not placed                    d
# 1           Placed                    d
# ...

# %%
del df["registered_for_ Placement_Training"]
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      68.0
# 3        4      M       A            71.0                      70.4
# 4        5      M       A             NaN                      65.5
#
#    B.Tech_percentage  Backlogs placement status Urban/Rural
# 0              40.00        18       Not placed       Urban
# 1              71.45         0           Placed       Rural
# 2              45.26        13       Not placed       Urban
# 3              36.47        17       Not placed       Urban
# 4              42.52        17       Not placed       Urban

# %%
df1=pd.DataFrame({'Roll No':[118],'Gender':["F"],'Section':["C"],"SSC Percentage":[99], 'B.Tech_percentage':[75],'Backlogs':[0],'placement status':["Not placed"], "hostler/days scholar":["h"]},index=[117]) 
df1
# Out:
#      Roll No Gender Section  SSC Percentage  B.Tech_percentage  Backlogs  \
# 117      118      F       C              99                 75         0
#
#     placement status hostler/days scholar
# 117       Not placed                    h

# %%
df=df.append(df1) 
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      68.0
# 3        4      M       A            71.0                      70.4
# 4        5      M       A             NaN                      65.5
#
#    B.Tech_percentage placement status hostler/days scholar  Backlogs
# 0              40.00       Not placed                    d       NaN
# 1              71.45           Placed                    d       NaN
# 2              45.26       Not placed                    d       NaN
# 3              36.47       Not placed                    d       NaN
# 4              42.52       Not placed                    h       NaN

# %%
df=df.drop(3) 
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A           87.30                      65.3
# 1        2      F       A           89.00                      92.4
# 2        3      F       A           67.00                      68.0
# 4        5      M       A             NaN                      65.5
# 5        6      M       A           81.26                      68.0
#
#    B.Tech_percentage  Backlogs placement status Urban/Rural
# 0              40.00        18       Not placed       Urban
# 1              71.45         0           Placed       Rural
# 2              45.26        13       Not placed       Urban
# 4              42.52        17       Not placed       Urban
# 5              62.20         6       Not placed       Rural

# %%
df.loc[1,'hostler/days scholar']='h' 
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A           87.30                      65.3
# 1        2      F       A           89.00                      92.4
# 2        3      F       A           67.00                      68.0
# 4        5      M       A             NaN                      65.5
# 5        6      M       A           81.26                      68.0
#
#    B.Tech_percentage placement status hostler/days scholar  Backlogs
# 0              40.00       Not placed                    d       NaN
# 1              71.45           Placed                    h       NaN
# 2              45.26       Not placed                    d       NaN
# 4              42.52       Not placed                    h       NaN
# 5              62.20       Not placed                    h       NaN

# %%
def incre(x): 
  if(x<70): 
    return(x+0.05) 
  else: 
    return(x)

# %%
df["B.Tech_percentage"]=df["B.Tech_percentage"].apply(incre) 
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A           87.30                      65.3
# 1        2      F       A           89.00                      92.4
# 2        3      F       A           67.00                      68.0
# 4        5      M       A             NaN                      65.5
# 5        6      M       A           81.26                      68.0
#
#    B.Tech_percentage placement status hostler/days scholar  Backlogs
# 0              40.10       Not placed                    d       NaN
# 1              71.45           Placed                    h       NaN
# 2              45.36       Not placed                    d       NaN
# 4              42.62       Not placed                    h       NaN
# 5              62.30       Not placed                    h       NaN

# %%
for index,rows in df[df["B.Tech_percentage"]>=80].iterrows(): 
  print(rows["Roll No"],"-",rows["B.Tech_percentage"])
# Out:
# 18 - 85.39
# 60 - 81.1
# 71 - 80.47
# 97 - 88.1
# 102 - 83.38

# %%
df.loc[[1,2],['SSC Percentage',"inter_Diploma_percentage"]]
# Out:
#    SSC Percentage  inter_Diploma_percentage
# 1            89.0                      92.4
# 2            67.0                      68.0

# %%
df["SSC Percentage"]=df["SSC Percentage"].replace(to_replace=np.nan,value=np.mean(df["S
SC Percentage"]))
df.head()
# Out:
#   File "<ipython-input-18-5c90e6bdb56e>", line 1
#     df["SSC Percentage"]=df["SSC Percentage"].replace(to_replace=np.nan,value=np.mean(df["S
#                                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd  
import numpy as np
df=pd.read_csv("students_placement_data.csv")
grouped=df.groupby("Gender")
grouped["B.Tech_percentage"].agg(np.mean)
# Out:
# Gender
# F    71.199388
# M    56.994265
# Name: B.Tech_percentage, dtype: float64

# %%
df2=pd.read_csv("urban_rural.csv") 
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      68.0
# 3        4      M       A            71.0                      70.4
# 4        5      M       A             NaN                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              71.45         0                                yes
# 2              45.26        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df=pd.merge(df,df2,on="Roll No") 
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A           87.30                      65.3
# 1        2      F       A           89.00                      92.4
# 2        3      F       A           67.00                      68.0
# 3        5      M       A             NaN                      65.5
# 4        6      M       A           81.26                      68.0
#
#    B.Tech_percentage  Backlogs placement status Urban/Rural_x Urban/Rural_y
# 0              40.00        18       Not placed         Urban         Urban
# 1              71.45         0           Placed         Rural         Rural
# 2              45.26        13       Not placed         Urban         Urban
# 3              42.52        17       Not placed         Urban         Urban
# 4              62.20         6       Not placed         Rural         Rural

# %%
df["SSC Percentage"].mean()
# Out:
# 80.55695652173912

# %%
df.plot(x="SSC Percentage",y="inter_Diploma_percentage")
# Out:
# <AxesSubplot:xlabel='SSC Percentage'>
